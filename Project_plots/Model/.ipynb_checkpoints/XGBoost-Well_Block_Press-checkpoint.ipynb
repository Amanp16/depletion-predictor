# %%
# !pip install pandas
# !pip install scikit-learn
# !pip install xgboost
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: xgboost in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (1.7.6)
# Requirement already satisfied: numpy in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from xgboost) (1.10.1)
# Requirement already satisfied: matplotlib in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\70003431\appdata\local\anaconda3\envs\projectproductivityindex\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### Setup
# Import required processing library

# %%
import pandas as pd
print(pd.__version__)
import numpy as np
print(np.__version__)
import xgboost as xg
print(xg.__version__)
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, r2_score
import matplotlib.pyplot as plt
# Out:
# 2.0.2
# 1.23.5
# 1.7.6

# %%
# check xgboost version
data_path = "..\Data\Final_Data_With_TVD.csv"
df = pd.read_csv(data_path)
print("\nLoaded Data :", data_path, "\n----------------------------------------------")
print("\n","\n",df.head())
# Out:
# Loaded Data : ..\Data\Final_Data_With_TVD.csv
# ----------------------------------------------
#
#
#     WELL  mTVDSS  Northing    Easting  \
# 0   107  2550.4  839440.1  2516323.0
# 1   107  2550.5  839440.1  2516323.0
# 2   107  2550.7  839440.2  2516323.0
# 3   107  2550.8  839440.2  2516323.0
# 4   107  2551.0  839440.2  2516323.0
#
#    ANGLE_FAIL.DEG                  :  Fail Angle  \
# 0                                         34.140
# 1                                         33.889
# 2                                         33.504
# 3                                         33.074
# 4                                         32.755
#
#    BRIT_IND.                     :  Brittleness Index  \
# 0                                             38.377
# 1                                             38.336
# 2                                             38.968
# 3                                             39.797
# 4                                             40.163
#
#    BRIT_PR.                     :  Brittleness Index from Poisson's Ratio  \
# 0                                             39.566
# 1                                             40.276
# 2                                             42.315
# 3                                             44.944
# 4                                             46.596
#
#    BRIT_YM.                     :  Brittleness Index from Young's Modulus  \
# 0                                             37.188
# 1                                             36.395
# 2                                             35.621
# 3                                             34.649
# 4                                             33.731
#
#     BRIT_AVG  CS   .M/MIN                 :  Compressive Strength  ...  \
# 0  38.377000                                            983.446    ...
# 1  38.335667                                            974.222    ...
# 2  38.968000                                            960.112    ...
# 3  39.796667                                            944.563    ...
# 4  40.163333                                            933.105    ...
#
#    SHMIN_GRAD.                     :  Horizontal Stress Gradient (Min)  \
# 0                                              1.685
# 1                                              1.681
# 2                                              1.670
# 3                                              1.657
# 4                                              1.648
#
#    STRESS_CUM.PSI                  :  Cumulative stress (SHPZ)  \
# 0                                          10745.905
# 1                                          10491.886
# 2                                          10292.826
# 3                                          10117.524
# 4                                           9955.089
#
#    UCS_BF.PSI                  :  Uniaxial Compressive Strength (BF)  \
# 0                                           1530.737
# 1                                           1508.828
# 2                                           1487.513
# 3                                           1460.926
# 4                                           1435.945
#
#    UCS_LAL.PSI                  :  Uniaxial Compressive Strength (lal)  \
# 0                                           3710.090
# 1                                           3655.972
# 2                                           3573.973
# 3                                           3484.724
# 4                                           3419.701
#
#    VP   .FT/S                 :  Compressional velocity  \
# 0                                          11673.283
# 1                                          11550.865
# 2                                          11365.380
# 3                                          11163.493
# 4                                          11016.407
#
#    VPVS .                     :  Vp / Vs ratio  \
# 0                                        1.813
# 1                                        1.807
# 2                                        1.790
# 3                                        1.769
# 4                                        1.756
#
#    VS   .FT/S                 :  Shear velocity  \
# 0                                      6439.337
# 1                                      6393.318
# 2                                      6350.295
# 3                                      6310.816
# 4                                      6271.913
#
#    YM   .                     :  Youngs' Modulus  \
# 0                                          3.603
# 1                                          3.548
# 2                                          3.493
# 3                                          3.425
# 4                                          3.361
#
#    YM_STAT.                     :  Youngs' Modulus (Static)  \
# 0                                              2.014
# 1                                              1.977
# 2                                              1.941
# 3                                              1.897
# 4                                              1.855
#
#    PRESS_PP.PSI                  :  Pore Pressure
# 0                                        4970.330
# 1                                        4970.452
# 2                                        4970.574
# 3                                        4970.696
# 4                                        4970.817
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Checking data distribution

# %%
## plotting the bar graph of data
# df.plot(kind = 'bar')

# %% [markdown]
# ### Normalization

# %%
df_max_scaled = df.copy()
i = 0  
# apply normalization techniques
for column in df_max_scaled.iloc[:,1:-1].columns:
        df_max_scaled[column] = df_max_scaled[column]  / df_max_scaled[column].abs().max()
      
## view normalized data
display(df_max_scaled)
# Out:
#        WELL    mTVDSS  Northing   Easting  \
# 0       107  0.726651  0.999859  0.999813
# 1       107  0.726680  0.999859  0.999813
# 2       107  0.726737  0.999859  0.999813
# 3       107  0.726765  0.999859  0.999813
# 4       107  0.726822  0.999859  0.999813
# ...     ...       ...       ...       ...
# 18097   105  0.976694  0.999555  1.000000
# 18098   105  0.976751  0.999555  1.000000
# 18099   105  0.976779  0.999555  1.000000
# 18100   105  0.976836  0.999555  1.000000
# 18101   105  0.976865  0.999555  1.000000
#
#        ANGLE_FAIL.DEG                  :  Fail Angle  \
# 0                                           0.715004
# 1                                           0.709747
# 2                                           0.701684
# 3                                           0.692678
# 4                                           0.685997
# ...                                              ...
# 18097                                       0.915284
# 18098                                       0.907975
# 18099                                       0.902132
# 18100                                       0.897148
# 18101                                       0.895661
#
#        BRIT_IND.                     :  Brittleness Index  \
# 0                                               0.347156
# 1                                               0.346785
# 2                                               0.352502
# 3                                               0.360001
# 4                                               0.363312
# ...                                                  ...
# 18097                                           0.661140
# 18098                                           0.621907
# 18099                                           0.606113
# 18100                                           0.625417
# 18101                                           0.640207
#
#        BRIT_PR.                     :  Brittleness Index from Poisson's Ratio  \
# 0                                               0.361241
# 1                                               0.367723
# 2                                               0.386340
# 3                                               0.410343
# 4                                               0.425425
# ...                                                  ...
# 18097                                           0.323406
# 18098                                           0.305630
# 18099                                           0.307227
# 18100                                           0.342406
# 18101                                           0.361332
#
#        BRIT_YM.                     :  Brittleness Index from Young's Modulus  \
# 0                                               0.216440
# 1                                               0.211824
# 2                                               0.207319
# 3                                               0.201662
# 4                                               0.196319
# ...                                                  ...
# 18097                                           0.644587
# 18098                                           0.605441
# 18099                                           0.584092
# 18100                                           0.586514
# 18101                                           0.593480
#
#        BRIT_AVG  CS   .M/MIN                 :  Compressive Strength  ...  \
# 0      0.347154                                           0.615942    ...
# 1      0.346781                                           0.610165    ...
# 2      0.352501                                           0.601328    ...
# 3      0.359997                                           0.591589    ...
# 4      0.363313                                           0.584413    ...
# ...         ...                                                ...    ...
# 18097  0.661135                                           0.868147    ...
# 18098  0.621906                                           0.857648    ...
# 18099  0.606108                                           0.849308    ...
# 18100  0.625415                                           0.842252    ...
# 18101  0.640205                                           0.840183    ...
#
#        SHMIN_GRAD.                     :  Horizontal Stress Gradient (Min)  \
# 0                                               0.875780
# 1                                               0.873701
# 2                                               0.867983
# 3                                               0.861227
# 4                                               0.856549
# ...                                                  ...
# 18097                                           0.822245
# 18098                                           0.829522
# 18099                                           0.828482
# 18100                                           0.814449
# 18101                                           0.807173
#
#        STRESS_CUM.PSI                  :  Cumulative stress (SHPZ)  \
# 0                                               0.588645
# 1                                               0.574730
# 2                                               0.563826
# 3                                               0.554223
# 4                                               0.545325
# ...                                                  ...
# 18097                                           0.728411
# 18098                                           0.755646
# 18099                                           0.755658
# 18100                                           0.722257
# 18101                                           0.728421
#
#        UCS_BF.PSI                  :  Uniaxial Compressive Strength (BF)  \
# 0                                               0.224674
# 1                                               0.221458
# 2                                               0.218329
# 3                                               0.214427
# 4                                               0.210760
# ...                                                  ...
# 18097                                           0.591911
# 18098                                           0.552689
# 18099                                           0.531779
# 18100                                           0.534135
# 18101                                           0.540932
#
#        UCS_LAL.PSI                  :  Uniaxial Compressive Strength (lal)  \
# 0                                               0.448915
# 1                                               0.442367
# 2                                               0.432445
# 3                                               0.421646
# 4                                               0.413778
# ...                                                  ...
# 18097                                           0.784574
# 18098                                           0.768618
# 18099                                           0.756068
# 18100                                           0.745536
# 18101                                           0.742463
#
#        VP   .FT/S                 :  Compressional velocity  \
# 0                                               0.531188
# 1                                               0.525618
# 2                                               0.517177
# 3                                               0.507990
# 4                                               0.501297
# ...                                                  ...
# 18097                                           0.816736
# 18098                                           0.803162
# 18099                                           0.792486
# 18100                                           0.783526
# 18101                                           0.780912
#
#        VPVS .                     :  Vp / Vs ratio  \
# 0                                         0.685444
# 1                                         0.683176
# 2                                         0.676749
# 3                                         0.668809
# 4                                         0.663894
# ...                                            ...
# 18097                                     0.699433
# 18098                                     0.706616
# 18099                                     0.706238
# 18100                                     0.692250
# 18101                                     0.685444
#
#        VS   .FT/S                 :  Shear velocity  \
# 0                                          0.557323
# 1                                          0.553340
# 2                                          0.549617
# 3                                          0.546200
# 4                                          0.542833
# ...                                             ...
# 18097                                      0.839504
# 18098                                      0.817164
# 18099                                      0.807053
# 18100                                      0.813876
# 18101                                      0.819375
#
#        YM   .                     :  Youngs' Modulus  \
# 0                                           0.276579
# 1                                           0.272357
# 2                                           0.268135
# 3                                           0.262915
# 4                                           0.258003
# ...                                              ...
# 18097                                       0.671912
# 18098                                       0.635757
# 18099                                       0.616028
# 18100                                       0.618254
# 18101                                       0.624703
#
#        YM_STAT.                     :  Youngs' Modulus (Static)  \
# 0                                               0.185144
# 1                                               0.181743
# 2                                               0.178434
# 3                                               0.174389
# 4                                               0.170528
# ...                                                  ...
# 18097                                           0.571061
# 18098                                           0.529877
# 18099                                           0.507906
# 18100                                           0.510388
# 18101                                           0.517466
#
#        PRESS_PP.PSI                  :  Pore Pressure
# 0                                            4970.330
# 1                                            4970.452
# 2                                            4970.574
# 3                                            4970.696
# 4                                            4970.817
# ...                                               ...
# 18097                                        5352.377
# 18098                                        5352.396
# 18099                                        5352.415
# 18100                                        5352.433
# 18101                                        5352.451
#
# [18102 rows x 35 columns]

# %%
## plotting after normalization
# df_max_scaled.plot(kind = 'bar')

# %% [markdown]
# ### Splitting
# ##### X,y splitting and then further dividing testing and training dataset

# %%
X, y = df_max_scaled.iloc[lambda x: x.index % 10 == 0, :-1], df_max_scaled.iloc[lambda x: x.index % 10 == 0, -1]
print("\n", X.head(), "\n", y.head())
# Out:
#      WELL    mTVDSS  Northing   Easting  \
# 0    107  0.726651  0.999859  0.999813
# 10   107  0.727078  0.999860  0.999813
# 20   107  0.727506  0.999860  0.999813
# 30   107  0.727905  0.999860  0.999812
# 40   107  0.728332  0.999861  0.999812
#
#     ANGLE_FAIL.DEG                  :  Fail Angle  \
# 0                                        0.715004
# 10                                       0.673787
# 20                                       0.657200
# 30                                       0.681830
# 40                                       0.702375
#
#     BRIT_IND.                     :  Brittleness Index  \
# 0                                            0.347156
# 10                                           0.328539
# 20                                           0.322189
# 30                                           0.366559
# 40                                           0.329579
#
#     BRIT_PR.                     :  Brittleness Index from Poisson's Ratio  \
# 0                                            0.361241
# 10                                           0.387033
# 20                                           0.391370
# 30                                           0.436792
# 40                                           0.350577
#
#     BRIT_YM.                     :  Brittleness Index from Young's Modulus  \
# 0                                            0.216440
# 10                                           0.176042
# 20                                           0.165106
# 30                                           0.193246
# 40                                           0.200615
#
#     BRIT_AVG  CS   .M/MIN                 :  Compressive Strength  ...  \
# 0   0.347154                                           0.615942    ...
# 10  0.328538                                           0.571418    ...
# 20  0.322188                                           0.554052    ...
# 30  0.366558                                           0.579953    ...
# 40  0.329575                                           0.602092    ...
#
#     SHMAX_GRAD.                     :  Horizontal Stress Gradient (Max)  \
# 0                                            0.958056
# 10                                           0.958448
# 20                                           0.958448
# 30                                           0.958840
# 40                                           0.958056
#
#     SHMIN_GRAD.                     :  Horizontal Stress Gradient (Min)  \
# 0                                            0.875780
# 10                                           0.867464
# 20                                           0.866424
# 30                                           0.852911
# 40                                           0.878378
#
#     STRESS_CUM.PSI                  :  Cumulative stress (SHPZ)  \
# 0                                            0.588645
# 10                                           0.557628
# 20                                           0.607571
# 30                                           0.548703
# 40                                           0.568738
#
#     UCS_BF.PSI                  :  Uniaxial Compressive Strength (BF)  \
# 0                                            0.224674
# 10                                           0.197043
# 20                                           0.189769
# 30                                           0.208662
# 40                                           0.213708
#
#     UCS_LAL.PSI                  :  Uniaxial Compressive Strength (lal)  \
# 0                                            0.448915
# 10                                           0.399724
# 20                                           0.381328
# 30                                           0.408927
# 40                                           0.433299
#
#     VP   .FT/S                 :  Compressional velocity  \
# 0                                            0.531188
# 10                                           0.489341
# 20                                           0.473691
# 30                                           0.497170
# 40                                           0.517903
#
#     VPVS .                     :  Vp / Vs ratio  \
# 0                                      0.685444
# 10                                     0.676371
# 20                                     0.674858
# 30                                     0.660491
# 40                                     0.689225
#
#     VS   .FT/S                 :  Shear velocity  \
# 0                                       0.557323
# 10                                      0.520214
# 20                                      0.504659
# 30                                      0.541176
# 40                                      0.540333
#
#     YM   .                     :  Youngs' Modulus  \
# 0                                        0.276579
# 10                                       0.239272
# 20                                       0.229216
# 30                                       0.255162
# 40                                       0.261994
#
#     YM_STAT.                     :  Youngs' Modulus (Static)
# 0                                            0.185144
# 10                                           0.156095
# 20                                           0.148465
# 30                                           0.168321
# 40                                           0.173561
#
# [5 rows x 34 columns]
#  0     4970.330
# 10    4971.548
# 20    4972.763
# 30    4973.977
# 40    4975.189
# Name: PRESS_PP.PSI                  :  Pore Pressure, dtype: float64

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y,
                      test_size = 0.3, random_state = 123)
print("\n", train_X.head(), "\n", test_X.head(), "\n\n\n", train_y.head(), "\n", test_y.head())
# Out:
#         WELL    mTVDSS  Northing   Easting  \
# 14150   105  0.805317  0.999556  1.000000
# 9630    106  0.896376  0.999622  0.999775
# 5660    107  0.969087  0.999991  0.999779
# 2860    107  0.849222  0.999922  0.999795
# 8070    106  0.829791  0.999590  0.999789
#
#        ANGLE_FAIL.DEG                  :  Fail Angle  \
# 14150                                       0.824495
# 9630                                        0.957255
# 5660                                        0.851826
# 2860                                        0.934154
# 8070                                        0.773100
#
#        BRIT_IND.                     :  Brittleness Index  \
# 14150                                           0.666413
# 9630                                            0.880404
# 5660                                            0.546157
# 2860                                            0.732521
# 8070                                            0.398600
#
#        BRIT_PR.                     :  Brittleness Index from Poisson's Ratio  \
# 14150                                           0.595692
# 9630                                            0.385691
# 5660                                            0.367404
# 2860                                            0.305721
# 8070                                            0.329012
#
#        BRIT_YM.                     :  Brittleness Index from Young's Modulus  \
# 14150                                           0.477811
# 9630                                            0.887025
# 5660                                            0.468592
# 2860                                            0.747720
# 8070                                            0.303183
#
#        BRIT_AVG  CS   .M/MIN                 :  Compressive Strength  ...  \
# 14150  0.666414                                           0.745311    ...
# 9630   0.880395                                           0.931087    ...
# 5660   0.546158                                           0.780596    ...
# 2860   0.732519                                           0.895927    ...
# 8070   0.398598                                           0.682374    ...
#
#        SHMAX_GRAD.                     :  Horizontal Stress Gradient (Max)  \
# 14150                                           0.969424
# 9630                                            0.979616
# 5660                                            0.991768
# 2860                                            0.974128
# 8070                                            0.969816
#
#        SHMIN_GRAD.                     :  Horizontal Stress Gradient (Min)  \
# 14150                                           0.787942
# 9630                                            0.822765
# 5660                                            0.802495
# 2860                                            0.860187
# 8070                                            0.860707
#
#        STRESS_CUM.PSI                  :  Cumulative stress (SHPZ)  \
# 14150                                           0.557349
# 9630                                            0.640395
# 5660                                            0.686171
# 2860                                            0.748346
# 8070                                            0.706296
#
#        UCS_BF.PSI                  :  Uniaxial Compressive Strength (BF)  \
# 14150                                           0.432701
# 9630                                            0.860132
# 5660                                            0.424501
# 2860                                            0.700685
# 8070                                            0.288100
#
#        UCS_LAL.PSI                  :  Uniaxial Compressive Strength (lal)  \
# 14150                                           0.608783
# 9630                                            0.883921
# 5660                                            0.656853
# 2860                                            0.827641
# 8070                                            0.527822
#
#        VP   .FT/S                 :  Compressional velocity  \
# 14150                                           0.667189
# 9630                                            0.901251
# 5660                                            0.708083
# 2860                                            0.853373
# 8070                                            0.598315
#
#        VPVS .                     :  Vp / Vs ratio  \
# 14150                                     0.620038
# 9630                                      0.676749
# 5660                                      0.683176
# 2860                                      0.706616
# 8070                                      0.697543
#
#        VS   .FT/S                 :  Shear velocity  \
# 14150                                      0.773618
# 9630                                       0.957473
# 5660                                       0.745306
# 2860                                       0.868296
# 8070                                       0.616928
#
#        YM   .                     :  Youngs' Modulus  \
# 14150                                       0.517924
# 9630                                        0.895678
# 5660                                        0.509404
# 2860                                        0.767099
# 8070                                        0.356644
#
#        YM_STAT.                     :  Youngs' Modulus (Static)
# 14150                                           0.403751
# 9630                                            0.853006
# 5660                                            0.395109
# 2860                                            0.685420
# 8070                                            0.251793
#
# [5 rows x 34 columns]
#         WELL    mTVDSS  Northing   Easting  \
# 8480    106  0.847285  0.999599  0.999785
# 6540    106  0.764431  0.999561  0.999802
# 2700    107  0.842384  0.999918  0.999796
# 7080    106  0.787509  0.999570  0.999797
# 15760   105  0.875207  0.999555  1.000000
#
#        ANGLE_FAIL.DEG                  :  Fail Angle  \
# 8480                                        0.909253
# 6540                                        0.752073
# 2700                                        0.964250
# 7080                                        0.917169
# 15760                                       0.762901
#
#        BRIT_IND.                     :  Brittleness Index  \
# 8480                                            0.643780
# 6540                                            0.247415
# 2700                                            0.867179
# 7080                                            0.635974
# 15760                                           0.388495
#
#        BRIT_PR.                     :  Brittleness Index from Poisson's Ratio  \
# 8480                                            0.343163
# 6540                                            0.172632
# 2700                                            0.331376
# 7080                                            0.280129
# 15760                                           0.337466
#
#        BRIT_YM.                     :  Brittleness Index from Young's Modulus  \
# 8480                                            0.609660
# 6540                                            0.208326
# 2700                                            0.904643
# 7080                                            0.639797
# 15760                                           0.284786
#
#        BRIT_AVG  CS   .M/MIN                 :  Compressive Strength  ...  \
# 8480   0.643779                                           0.859476    ...
# 6540   0.247414                                           0.657790    ...
# 2700   0.867176                                           0.942021    ...
# 7080   0.635972                                           0.870909    ...
# 15760  0.388491                                           0.670372    ...
#
#        SHMAX_GRAD.                     :  Horizontal Stress Gradient (Max)  \
# 8480                                            0.972560
# 6540                                            0.958448
# 2700                                            0.973736
# 7080                                            0.963152
# 15760                                           0.976088
#
#        SHMIN_GRAD.                     :  Horizontal Stress Gradient (Min)  \
# 8480                                            0.851871
# 6540                                            0.932432
# 2700                                            0.853430
# 7080                                            0.889813
# 15760                                           0.845114
#
#        STRESS_CUM.PSI                  :  Cumulative stress (SHPZ)  \
# 8480                                            0.643457
# 6540                                            0.391381
# 2700                                            0.717059
# 7080                                            0.634049
# 15760                                           0.721360
#
#        UCS_BF.PSI                  :  Uniaxial Compressive Strength (BF)  \
# 8480                                            0.556863
# 6540                                            0.219027
# 2700                                            0.881320
# 7080                                            0.587052
# 15760                                           0.274183
#
#        UCS_LAL.PSI                  :  Uniaxial Compressive Strength (lal)  \
# 8480                                            0.771384
# 6540                                            0.497844
# 2700                                            0.901827
# 7080                                            0.788801
# 15760                                           0.513072
#
#        VP   .FT/S                 :  Compressional velocity  \
# 8480                                            0.805515
# 6540                                            0.572813
# 2700                                            0.916484
# 7080                                            0.820331
# 15760                                           0.585767
#
#        VPVS .                     :  Vp / Vs ratio  \
# 8480                                      0.691871
# 6540                                      0.773913
# 2700                                      0.696408
# 7080                                      0.717580
# 15760                                     0.694140
#
#        VS   .FT/S                 :  Shear velocity  \
# 8480                                       0.837059
# 6540                                       0.532231
# 2700                                       0.946238
# 7080                                       0.821932
# 15760                                      0.606821
#
#        YM   .                     :  Youngs' Modulus  \
# 8480                                        0.639595
# 6540                                        0.269133
# 2700                                        0.911952
# 7080                                        0.667460
# 15760                                       0.339679
#
#        YM_STAT.                     :  Youngs' Modulus (Static)
# 8480                                            0.534197
# 6540                                            0.179169
# 2700                                            0.875253
# 7080                                            0.566005
# 15760                                           0.237176
#
# [5 rows x 34 columns]
#
#
#  14150    5127.453
# 9630     5286.266
# 5660     5356.636
# 2860     5241.139
# 8070     5179.696
# Name: PRESS_PP.PSI                  :  Pore Pressure, dtype: float64
#  8480     5212.136
# 6540     5030.448
# 2700     5230.079
# 7080     5088.186
# 15760    5255.936
# Name: PRESS_PP.PSI                  :  Pore Pressure, dtype: float64

# %% [markdown]
# ### Instantiation

# %%
# Train and test set are converted to DMatrix objects,
# as it is required by learning API.
train_dmatrix = xg.DMatrix(data = train_X, label = train_y)
test_dmatrix = xg.DMatrix(data = test_X, label = test_y)
# xgb_r = xg.XGBRegressor(objective ='reg:linear',
#                   n_estimators = 10, seed = 123)

# %%
# Parameter dictionary specifying base learner
param = {"eta":0.3,
         "booster":"gblinear", "objective":"reg:linear"}
epochs = 5000
# params={"max_depth" : 4,
#          "eta":0.3,
#         'objective':'reg:squarederror'}
# cv_results = xg.cv(dtrain=train_dmatrix, params=params, nfold=3, metrics={'rmse'}, as_pandas=True, seed=20)
# print('RMSE: %.2f' % cv_results['test-rmse-mean'].min())  
xgb_r = xg.train(params = param, dtrain = train_dmatrix, num_boost_round = epochs)
pred = xgb_r.predict(test_dmatrix)
rmse = np.sqrt(MSE(test_y, pred))
print("RMSE : % f" %(rmse))
r2_score(test_y,pred)
# Out:
# [10:09:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE :  22.460221
# 0.9675756289522386

# %%
# accuracy_score(test_y, pred)
# import sklearn

# %%
##Predictions
rmse = np.sqrt(MSE(test_y, pred))
print("RMSE : % f" %(rmse))
r2_scor = r2_score(test_y,pred)
print("\n R^2 Score: %f" %(r2_scor))
# print("\n testing values: ", test_y, pred)
plt.plot(test_y,pred)
# print("predicted values: \n ", pred, "\n")
# Out:
# RMSE :  22.460221
#
#  R^2 Score: 0.967576

# %% [markdown]
# ### Hyperparameter tuning
#
# For hyperparameter tuning of different paramters to increase the accuracy.

# %%
# hyper_X, hyper_y = df.iloc[lambda x: x.index % 1000 == 0, :-1], df.iloc[lambda x: x.index % 1000 == 0, -1]

# hypertrain_X, hypertest_X, hypertrain_y, hypertest_y = train_test_split(hyper_X, hyper_y,
#                       test_size = 0.3, random_state = 123)

# %%
import xgboost as xgb
import sklearn
from sklearn.model_selection import GridSearchCV

# Define the hyperparameter grid
param_grid = {
    'learning_rate': [0.03,0.09,0.1,0.3], 'n_estimators': [500,1000,5000,10000]
}

# Create the XGBoost model object
xgb_model = xgb.XGBRegressor()

# Create the GridSearchCV object
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='neg_mean_squared_error', verbose=1)
print("done grid search")
# Fit the GridSearchCV object to the training data
grid_search.fit(train_X, train_y)

# Print the best set of hyperparameters and the corresponding score
print("Best set of hyperparameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# done grid search
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best set of hyperparameters:  {'learning_rate': 0.03, 'n_estimators': 500}
# Best score:  -1.6406422220091077

# %% [markdown]
# ### Feature importance calculation

# %%
xgb_r.get_score(importance_type='weight')

# plt.bar(range(len(feature_importance)), list(feature_importance.values()), align='center')
# plt.show()
# plt.xticks(range(len(feature_importance)), list(feature_importance.keys()))
# Out:
# {'WELL': 9.038772583007812,
#  'mTVDSS': 95.25675964355469,
#  'Northing': -140.7628936767578,
#  'Easting': 155.44900512695312,
#  'ANGLE_FAIL.DEG                  :  Fail Angle': -177.47975158691406,
#  'BRIT_IND.                     :  Brittleness Index': 341.49029541015625,
#  "BRIT_PR.                     :  Brittleness Index from Poisson's Ratio": 1601.5107421875,
#  "BRIT_YM.                     :  Brittleness Index from Young's Modulus": -518.918701171875,
#  'BRIT_AVG': 583.6343994140625,
#  'CS   .M/MIN                 :  Compressive Strength': -308.43719482421875,
#  'DTCO .US/F                 :  Compressional slowness': -258.3297119140625,
#  'DTSM .US/F                 :  Fast Shear Slowness': -10.479111671447754,
#  'IP   .RAYL/M2                 :  P Impedence': -326.14337158203125,
#  'IS   .RAYL/M2                 :  S Impedance': 478.9371643066406,
#  'KBULK.                     :  Bulk Mudulus': 2220.260986328125,
#  'LAMBDA.                     :  Lambda': -1743.320556640625,
#  'LAMRHO.                     :  ': -391.48150634765625,
#  'MU   .CP                   :  Mu': 450.8934326171875,
#  "PR   .                     :  Poisson's ratio": 1140.4031982421875,
#  'PRESS_OB.PSI                  :  Over-burden Pressure': -12.684813499450684,
#  'PRESS_SHMAX.PSI                  :  Horizontal Stress (Max)': 207.9425048828125,
#  'PRESS_SHMIN.PSI                  :  Horizontal Stress (Min)': 246.20176696777344,
#  "PR_STAT.                     :  Poisson's ratio (Static)": 1165.20751953125,
#  'PZS  .PSI                  :  Processed Zone Stress': -595.4744262695312,
#  'SHMAX_GRAD.                     :  Horizontal Stress Gradient (Max)': -55.681697845458984,
#  'SHMIN_GRAD.                     :  Horizontal Stress Gradient (Min)': -91.85091400146484,
#  'STRESS_CUM.PSI                  :  Cumulative stress (SHPZ)': 1720.543701171875,
#  'UCS_BF.PSI                  :  Uniaxial Compressive Strength (BF)': -603.2543334960938,
#  'UCS_LAL.PSI                  :  Uniaxial Compressive Strength (lal)': -449.95184326171875,
#  'VP   .FT/S                 :  Compressional velocity': 201.78042602539062,
#  'VPVS .                     :  Vp / Vs ratio': -239.75148010253906,
#  'VS   .FT/S                 :  Shear velocity': 298.0287170410156,
#  "YM   .                     :  Youngs' Modulus": -445.5296325683594,
#  "YM_STAT.                     :  Youngs' Modulus (Static)": 339.9014587402344}

# %%
feature_importance = xgb_r.get_score(importance_type='weight')
y=list(feature_importance.keys())
 
# getting values against each value of y
x=list(feature_importance.values())
plt.barh(y, x)
# setting label of y-axis
plt.ylabel("param")
plt.yticks(fontsize = 5) 
# setting label of x-axis
plt.xlabel("importance")
plt.title("Feature Importance")
plt.show()

# %% [markdown]
# ### After Feature Selection

# %%
# print(feature_importance.keys())
drop_col = []
thres = 200
j = -1
for val in feature_importance.values():
    j+=1
    if(abs(val)<thres):
        for i,v in enumerate(feature_importance):
            if i == 0 or i == 1 or i == 2 or i == 3:
                continue
            if i == j:
                drop_col.append(v)
                print(v)
# Out:
# ANGLE_FAIL.DEG                  :  Fail Angle
# DTSM .US/F                 :  Fast Shear Slowness
# PRESS_OB.PSI                  :  Over-burden Pressure
# SHMAX_GRAD.                     :  Horizontal Stress Gradient (Max)
# SHMIN_GRAD.                     :  Horizontal Stress Gradient (Min)

# %%
# drop_col = []
df_drop_col_scaled = df_max_scaled.drop(drop_col,axis = 1)
# df.drop(['A'], axis=1)

# %% [markdown]
# ### Repeating the process again

# %%
X, y = df_drop_col_scaled.iloc[lambda x: x.index % 10 == 0, 1:-1], df_drop_col_scaled.iloc[lambda x: x.index % 10 == 0, -1]
# print("\n", X.head(), "\n", y.head())
train_X, test_X, train_y, test_y = train_test_split(X, y,
                      test_size = 0.3, random_state = 123)
print("\n", train_X.head(), "\n", test_X.head(), "\n\n\n", train_y.head(), "\n", test_y.head())
# Out:
#           mTVDSS  Northing   Easting  \
# 14150  0.805317  0.999556  1.000000
# 9630   0.896376  0.999622  0.999775
# 5660   0.969087  0.999991  0.999779
# 2860   0.849222  0.999922  0.999795
# 8070   0.829791  0.999590  0.999789
#
#        BRIT_IND.                     :  Brittleness Index  \
# 14150                                           0.666413
# 9630                                            0.880404
# 5660                                            0.546157
# 2860                                            0.732521
# 8070                                            0.398600
#
#        BRIT_PR.                     :  Brittleness Index from Poisson's Ratio  \
# 14150                                           0.595692
# 9630                                            0.385691
# 5660                                            0.367404
# 2860                                            0.305721
# 8070                                            0.329012
#
#        BRIT_YM.                     :  Brittleness Index from Young's Modulus  \
# 14150                                           0.477811
# 9630                                            0.887025
# 5660                                            0.468592
# 2860                                            0.747720
# 8070                                            0.303183
#
#        BRIT_AVG  CS   .M/MIN                 :  Compressive Strength  \
# 14150  0.666414                                           0.745311
# 9630   0.880395                                           0.931087
# 5660   0.546158                                           0.780596
# 2860   0.732519                                           0.895927
# 8070   0.398598                                           0.682374
#
#        DTCO .US/F                 :  Compressional slowness  \
# 14150                                           0.571817
# 9630                                            0.423304
# 5660                                            0.538784
# 2860                                            0.447056
# 8070                                            0.637639
#
#        IP   .RAYL/M2                 :  P Impedence  ...  \
# 14150                                      0.593587  ...
# 9630                                       0.856258  ...
# 5660                                       0.628440  ...
# 2860                                       0.827228  ...
# 8070                                       0.537373  ...
#
#        PR_STAT.                     :  Poisson's ratio (Static)  \
# 14150                                           0.490667
# 9630                                            0.656000
# 5660                                            0.669333
# 2860                                            0.720000
# 8070                                            0.701333
#
#        PZS  .PSI                  :  Processed Zone Stress  \
# 14150                                           0.775901
# 9630                                            0.699511
# 5660                                            0.671763
# 2860                                            0.999998
# 8070                                            0.967100
#
#        STRESS_CUM.PSI                  :  Cumulative stress (SHPZ)  \
# 14150                                           0.557349
# 9630                                            0.640395
# 5660                                            0.686171
# 2860                                            0.748346
# 8070                                            0.706296
#
#        UCS_BF.PSI                  :  Uniaxial Compressive Strength (BF)  \
# 14150                                           0.432701
# 9630                                            0.860132
# 5660                                            0.424501
# 2860                                            0.700685
# 8070                                            0.288100
#
#        UCS_LAL.PSI                  :  Uniaxial Compressive Strength (lal)  \
# 14150                                           0.608783
# 9630                                            0.883921
# 5660                                            0.656853
# 2860                                            0.827641
# 8070                                            0.527822
#
#        VP   .FT/S                 :  Compressional velocity  \
# 14150                                           0.667189
# 9630                                            0.901251
# 5660                                            0.708083
# 2860                                            0.853373
# 8070                                            0.598315
#
#        VPVS .                     :  Vp / Vs ratio  \
# 14150                                     0.620038
# 9630                                      0.676749
# 5660                                      0.683176
# 2860                                      0.706616
# 8070                                      0.697543
#
#        VS   .FT/S                 :  Shear velocity  \
# 14150                                      0.773618
# 9630                                       0.957473
# 5660                                       0.745306
# 2860                                       0.868296
# 8070                                       0.616928
#
#        YM   .                     :  Youngs' Modulus  \
# 14150                                       0.517924
# 9630                                        0.895678
# 5660                                        0.509404
# 2860                                        0.767099
# 8070                                        0.356644
#
#        YM_STAT.                     :  Youngs' Modulus (Static)
# 14150                                           0.403751
# 9630                                            0.853006
# 5660                                            0.395109
# 2860                                            0.685420
# 8070                                            0.251793
#
# [5 rows x 28 columns]
#           mTVDSS  Northing   Easting  \
# 8480   0.847285  0.999599  0.999785
# 6540   0.764431  0.999561  0.999802
# 2700   0.842384  0.999918  0.999796
# 7080   0.787509  0.999570  0.999797
# 15760  0.875207  0.999555  1.000000
#
#        BRIT_IND.                     :  Brittleness Index  \
# 8480                                            0.643780
# 6540                                            0.247415
# 2700                                            0.867179
# 7080                                            0.635974
# 15760                                           0.388495
#
#        BRIT_PR.                     :  Brittleness Index from Poisson's Ratio  \
# 8480                                            0.343163
# 6540                                            0.172632
# 2700                                            0.331376
# 7080                                            0.280129
# 15760                                           0.337466
#
#        BRIT_YM.                     :  Brittleness Index from Young's Modulus  \
# 8480                                            0.609660
# 6540                                            0.208326
# 2700                                            0.904643
# 7080                                            0.639797
# 15760                                           0.284786
#
#        BRIT_AVG  CS   .M/MIN                 :  Compressive Strength  \
# 8480   0.643779                                           0.859476
# 6540   0.247414                                           0.657790
# 2700   0.867176                                           0.942021
# 7080   0.635972                                           0.870909
# 15760  0.388491                                           0.670372
#
#        DTCO .US/F                 :  Compressional slowness  \
# 8480                                            0.473616
# 6540                                            0.666027
# 2700                                            0.416270
# 7080                                            0.465064
# 15760                                           0.651296
#
#        IP   .RAYL/M2                 :  P Impedence  ...  \
# 8480                                       0.707287  ...
# 6540                                       0.501561  ...
# 2700                                       0.895170  ...
# 7080                                       0.767205  ...
# 15760                                      0.518997  ...
#
#        PR_STAT.                     :  Poisson's ratio (Static)  \
# 8480                                            0.690667
# 6540                                            0.824000
# 2700                                            0.698667
# 7080                                            0.738667
# 15760                                           0.693333
#
#        PZS  .PSI                  :  Processed Zone Stress  \
# 8480                                            0.758515
# 6540                                            0.039053
# 2700                                            0.944159
# 7080                                            0.795707
# 15760                                           0.933635
#
#        STRESS_CUM.PSI                  :  Cumulative stress (SHPZ)  \
# 8480                                            0.643457
# 6540                                            0.391381
# 2700                                            0.717059
# 7080                                            0.634049
# 15760                                           0.721360
#
#        UCS_BF.PSI                  :  Uniaxial Compressive Strength (BF)  \
# 8480                                            0.556863
# 6540                                            0.219027
# 2700                                            0.881320
# 7080                                            0.587052
# 15760                                           0.274183
#
#        UCS_LAL.PSI                  :  Uniaxial Compressive Strength (lal)  \
# 8480                                            0.771384
# 6540                                            0.497844
# 2700                                            0.901827
# 7080                                            0.788801
# 15760                                           0.513072
#
#        VP   .FT/S                 :  Compressional velocity  \
# 8480                                            0.805515
# 6540                                            0.572813
# 2700                                            0.916484
# 7080                                            0.820331
# 15760                                           0.585767
#
#        VPVS .                     :  Vp / Vs ratio  \
# 8480                                      0.691871
# 6540                                      0.773913
# 2700                                      0.696408
# 7080                                      0.717580
# 15760                                     0.694140
#
#        VS   .FT/S                 :  Shear velocity  \
# 8480                                       0.837059
# 6540                                       0.532231
# 2700                                       0.946238
# 7080                                       0.821932
# 15760                                      0.606821
#
#        YM   .                     :  Youngs' Modulus  \
# 8480                                        0.639595
# 6540                                        0.269133
# 2700                                        0.911952
# 7080                                        0.667460
# 15760                                       0.339679
#
#        YM_STAT.                     :  Youngs' Modulus (Static)
# 8480                                            0.534197
# 6540                                            0.179169
# 2700                                            0.875253
# 7080                                            0.566005
# 15760                                           0.237176
#
# [5 rows x 28 columns]
#
#
#  14150    5127.453
# 9630     5286.266
# 5660     5356.636
# 2860     5241.139
# 8070     5179.696
# Name: PRESS_PP.PSI                  :  Pore Pressure, dtype: float64
#  8480     5212.136
# 6540     5030.448
# 2700     5230.079
# 7080     5088.186
# 15760    5255.936
# Name: PRESS_PP.PSI                  :  Pore Pressure, dtype: float64

# %%
# Train and test set are converted to DMatrix objects,
# as it is required by learning API.
train_dmatrix = xg.DMatrix(data = train_X, label = train_y)
test_dmatrix = xg.DMatrix(data = test_X, label = test_y)
# xgb_r = xg.XGBRegressor(objective ='reg:linear',
#                   n_estimators = 10, seed = 123)

# %%
# Parameter dictionary specifying base learner
param = {"eta":0.03,
         "booster":"gblinear", "objective":"reg:linear"}
epochs = 5000
xgb_r = xg.train(params = param, dtrain = train_dmatrix, num_boost_round = epochs)
pred = xgb_r.predict(test_dmatrix)
rmse = np.sqrt(MSE(test_y, pred))
print("RMSE : % f" %(rmse))
r2_score(test_y,pred)
# Out:
# [10:17:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE :  26.970363
# 0.9532461784243307

# %%
##Predictions
rmse = np.sqrt(MSE(test_y, pred))
print("RMSE : % f" %(rmse))
r2_scor = r2_score(test_y,pred)
print("\n R^2 Score: %f" %(r2_scor))
plt.plot(test_y, pred)
# print("predicted values: \n ", pred, "\n")
# Out:
# RMSE :  26.970363
#
#  R^2 Score: 0.953246

# %% [markdown]
# ### Visualizing the results

# %%
df_107 = df_drop_col_scaled.iloc[:6000]
# X_TVD_107 = df[:6000:100]['mTVDSS']
X_107, y_107 = df_107.iloc[lambda x: x.index % 149 == 0, 1:-1], df_107.iloc[lambda x: x.index % 149 == 0, -1]
test_dmatrix_107 = xg.DMatrix(data = X_107, label = y_107)
# X_TVD_107

# %%
plt.scatter(X_107['mTVDSS']*df['mTVDSS'].abs().max(),y_107, color = 'red', s = 2)
plt.scatter(X_107['mTVDSS']*df['mTVDSS'].abs().max(), xgb_r.predict(test_dmatrix_107), color = 'blue', s=2)
plt.title('XGBoost comparison')
plt.xlabel('True Vertical Depth from Surface')
plt.ylabel('Pore_Pressure Predicted')
plt.show()

# %% [markdown]
# ### Hyperparam tuning again for new dataset

# %%
param_grid = {
    'learning_rate': [0.01,0.03,0.1,0.3], 'n_estimators': [1000,2000,5000,10000]
}

# Create the XGBoost model object
xgb_model = xgb.XGBRegressor(verbose=1)

# Create the GridSearchCV object
grid_search = GridSearchCV(xgb_model, param_grid,refit = True, cv=5, scoring='neg_mean_squared_error', verbose=1)
print("done grid search")
# Fit the GridSearchCV object to the training data
grid_search.fit(train_X, train_y)

# Print the best set of hyperparameters and the corresponding score
print("Best set of hyperparameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# done grid search
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [10:18:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:18:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:18:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:18:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:18:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:18:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:18:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:18:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:18:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:18:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:18:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:19:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:19:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:19:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:19:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:19:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:20:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:20:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:20:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:20:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:21:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:21:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:21:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:21:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:21:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:21:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:21:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:21:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:21:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:21:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:21:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:22:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:22:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:22:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:22:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:22:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:23:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:23:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:23:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:24:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:24:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:24:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
# [10:24:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:24:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:24:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:24:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:24:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:24:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:24:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:24:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:25:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:25:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:25:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:25:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:25:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:26:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:26:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:26:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:27:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:27:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:27:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:28:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:28:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:28:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:28:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:28:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:28:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:28:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:28:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:28:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:28:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:28:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:29:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:29:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:29:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:29:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:30:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:30:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:30:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:31:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [10:31:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# Best set of hyperparameters:  {'learning_rate': 0.01, 'n_estimators': 2000}
# Best score:  -1.315304220288199

# %% [markdown]
# ### Second Time Feature Selection

# %%
xgb_r.get_score(importance_type='weight')
# Out:
# {'mTVDSS': 531.5551147460938,
#  'Northing': 384.78411865234375,
#  'Easting': 365.5791931152344,
#  'BRIT_IND.                     :  Brittleness Index': 99.2452621459961,
#  "BRIT_PR.                     :  Brittleness Index from Poisson's Ratio": 970.0482788085938,
#  "BRIT_YM.                     :  Brittleness Index from Young's Modulus": -79.73272705078125,
#  'BRIT_AVG': 103.68727111816406,
#  'CS   .M/MIN                 :  Compressive Strength': 284.8180236816406,
#  'DTCO .US/F                 :  Compressional slowness': 832.0857543945312,
#  'IP   .RAYL/M2                 :  P Impedence': 221.32969665527344,
#  'IS   .RAYL/M2                 :  S Impedance': 184.1873016357422,
#  'KBULK.                     :  Bulk Mudulus': -103.08932495117188,
#  'LAMBDA.                     :  Lambda': -6.819821357727051,
#  'LAMRHO.                     :  ': -155.17295837402344,
#  'MU   .CP                   :  Mu': -101.05154418945312,
#  "PR   .                     :  Poisson's ratio": 468.3280334472656,
#  'PRESS_SHMAX.PSI                  :  Horizontal Stress (Max)': 432.5401611328125,
#  'PRESS_SHMIN.PSI                  :  Horizontal Stress (Min)': 460.6074523925781,
#  "PR_STAT.                     :  Poisson's ratio (Static)": 463.062744140625,
#  'PZS  .PSI                  :  Processed Zone Stress': -125.2210693359375,
#  'STRESS_CUM.PSI                  :  Cumulative stress (SHPZ)': 334.9403076171875,
#  'UCS_BF.PSI                  :  Uniaxial Compressive Strength (BF)': -149.44549560546875,
#  'UCS_LAL.PSI                  :  Uniaxial Compressive Strength (lal)': 333.4907531738281,
#  'VP   .FT/S                 :  Compressional velocity': 303.8965148925781,
#  'VPVS .                     :  Vp / Vs ratio': 490.3597106933594,
#  'VS   .FT/S                 :  Shear velocity': 354.48565673828125,
#  "YM   .                     :  Youngs' Modulus": 28.16312599182129,
#  "YM_STAT.                     :  Youngs' Modulus (Static)": -274.42041015625}

# %%
feature_importance = xgb_r.get_score(importance_type='weight')
y=list(feature_importance.keys())
 
# getting values against each value of y
x=list(feature_importance.values())
plt.barh(y, x)
# setting label of y-axis
plt.ylabel("param")
plt.yticks(fontsize = 5) 
# setting label of x-axis
plt.xlabel("importance")
plt.title("Feature Importance")
plt.show()
